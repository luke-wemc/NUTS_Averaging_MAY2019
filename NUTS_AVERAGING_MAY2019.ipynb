# %%
# NUTS Averaging V3
# if running on C3S_Energy VM, activate conda before running: source activate c3s_wemc
# luke.sanger@wemcouncil.org

# import packages
import iris
import geopandas as gpd
import pandas as pd
import numpy as np
import iris.pandas
import iris.analysis.cartography
import shapely
import glob, os
import warnings
import time

# import c3s filename utilites
import sys
sys.path.append(os.path.abspath("/Users/user/Documents/ERA5/luke_scripts/filename_example/"))
from filename_utilities import print_structure, print_elements, check_filename

# %%
# IMPORTANT: place this file in directory where ERA5 files are located and define path below:
path = r'/Users/user/Desktop/nuts_test_v3'
allFiles = [os.path.basename(x) for x in glob.glob(path + r"/*.nc")]

# IMPORTANT: specify one nuts level for processing .nc files (Must be nut0 or nut2)
# nuts = 'nut0'
nuts = 'nut2'

if nuts == 'nut0':
# load nuts0 country regions for processing
    path2 = r'/Users/user/Documents/ERA5/nuts0_masked_nc/'
    nutsFiles = [os.path.basename(x) for x in glob.glob(path2 + r"/*.nc")]
elif nuts == 'nut2':
# load nuts2 sub-country regions for processing
    path2 = r'/Users/user/Documents/ERA5/nuts2_masked_nc/'
    nutsFiles = [os.path.basename(x) for x in glob.glob(path2 + r"/*.nc")]

# get first cube in list to get cosine weights
nutslist2 = iris.load(path2 + nutsFiles[0])
nutcube2 = nutslist2[0]
nutcube2 = nutcube2.intersection(longitude=(-180, 180))
lats2 = nutcube2.coord('latitude').points
lons2 = nutcube2.coord('longitude').points

# get array of latitudes from nutcube
cos_lat = iris.analysis.cartography.cosine_latitude_weights(nutcube2)

# hide pointless iris warning message about lat/lon
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# run timer for measuring operation speed
start = time.time()

# literate through nc files for processing
for file_ in allFiles:
    cubelist = iris.load(file_)
    cube = cubelist[0]
    cube = cube.intersection(longitude=(-180, 180))
    df = pd.DataFrame()
    name = os.path.splitext(file_)[0]
    print('loaded ' + name + ' for ' + nuts + ' averaging')

    # iterate through nuts regions 
    for nut in nutsFiles:
        nutslist = iris.load(path2 + nut)
        nutcube = nutslist[0]
        nutcube = nutcube.intersection(longitude=(-180, 180))
        lats = nutcube.coord('latitude').points
        lons = nutcube.coord('longitude').points

        # get NUTSID from filename for column naming
        if nuts == 'nut0':     
            edit = str(nut)
            NUTSID = edit[:-15]
            print('processing ' + NUTSID + ' area, level = ' + nuts)
        elif nuts == 'nut2':
            edit = str(nut)
            NUTSID = edit[:-13]
            print('processing ' + NUTSID + ' area, level = ' + nuts)    
        
        # multiply region by cosine lats
        lsm_cos_lat = nutcube.copy()
        lsm_cos_lat.data *= cos_lat
        
        # apply the lsm_cos_lat to the main cube
        cube_lsm_cos_lat = cube.copy()
        cube_lsm_cos_lat.data *= lsm_cos_lat.data
        
        #sum of lsm_cos_lat 
        lsm_cos_lat_sum = lsm_cos_lat.collapsed(['latitude','longitude'], iris.analysis.SUM, weights=None)

        # sum of mc_lsm_cos_lat
        cube_lsm_cos_lat_sum = cube_lsm_cos_lat.collapsed(['latitude','longitude'], iris.analysis.SUM, weights=None)
        
        # divide sum of cube_lsm_cos_lat by sum of lsm_cos_lat
        end_nuts_lsm_cos_lat_sum = cube_lsm_cos_lat_sum.copy()
        end_nuts_lsm_cos_lat_sum.data /= lsm_cos_lat_sum.data
        
        # save as series, rename colume to NUTSID and concat to dataframe
        dfs = iris.pandas.as_series(end_nuts_lsm_cos_lat_sum, copy=True)
        dfs.rename(columns={1: NUTSID}, inplace=True) 
        df = pd.concat((df, dfs.rename(NUTSID)), axis=1)
    
    # organise dataframe columns alphabetically
    df1 = df.groupby(axis=1, level=0).first() 
    
    # save dataframe as csv
    n1 = str(name)
    n2 = n1.rstrip(".nc")
    csv_name = n2[:32] + nuts + n2[36:] + ".csv"
    df1.to_csv(csv_name)
    print(csv_name +' created')
    check_filename(csv_name)
    
print(nuts + ' processing complete')
end = time.time()
print('time elapsed in seconds:')
print(end - start)
# Out:
# loaded H_ERA5_ECMW_T639_GHI_0000m_Euro_025d_S200001010000_E200001012300_ACC_MAP_01h_NA-_noc_org_NA_NA---_NA---_NA--- for nut2 averaging
# processing FRK2 area, level = nut2
# processing ITH2 area, level = nut2
# processing TR33 area, level = nut2
# processing ITH5 area, level = nut2
# processing UKK1 area, level = nut2
# processing TR61 area, level = nut2
# processing NO01 area, level = nut2
# processing EL42 area, level = nut2
# processing NO06 area, level = nut2
# processing CH02 area, level = nut2
# processing FRY4 area, level = nut2
# processing TR21 area, level = nut2
# processing UKJ4 area, level = nut2
# processing PL42 area, level = nut2
# processing CH05 area, level = nut2
# processing UKJ3 area, level = nut2
# processing FRY3 area, level = nut2
# processing AT32 area, level = nut2
# processing DEA5 area, level = nut2
# processing BE10 area, level = nut2
# processing DEA2 area, level = nut2
# processing TR10 area, level = nut2
# processing UKI5 area, level = nut2
# processing FRI1 area, level = nut2
# processing TR42 area, level = nut2
# processing PL21 area, level = nut2
# processing DE92 area, level = nut2
# processing EL61 area, level = nut2
# processing BE21 area, level = nut2
# processing DEB3 area, level = nut2
# processing PL61 area, level = nut2
# processing UKM5 area, level = nut2
# processing DE80 area, level = nut2
# processing BE34 area, level = nut2
# processing AT11 area, level = nut2
# processing CZ01 area, level = nut2
# processing BE33 area, level = nut2
# processing CZ06 area, level = nut2
# processing FRY2 area, level = nut2
# processing TR72 area, level = nut2
# processing UKJ2 area, level = nut2
# processing LT01 area, level = nut2
# processing CH04 area, level = nut2
# processing FR10 area, level = nut2
# processing ITI1 area, level = nut2
# processing PL43 area, level = nut2
# processing FRJ1 area, level = nut2
# processing FRY5 area, level = nut2
# processing CH03 area, level = nut2
# processing DEA3 area, level = nut2
# processing EL51 area, level = nut2
# processing AT34 area, level = nut2
# processing DEA4 area, level = nut2
# processing AT33 area, level = nut2
# processing ITH4 area, level = nut2
# processing TR32 area, level = nut2
# processing PL51 area, level = nut2
# processing ITH3 area, level = nut2
# processing NO07 area, level = nut2
# processing EL43 area, level = nut2
# processing AT21 area, level = nut2
# processing TR51 area, level = nut2
# processing UKH1 area, level = nut2
# processing LU00 area, level = nut2
# processing FRM0 area, level = nut2
# processing BE32 area, level = nut2
# processing CZ07 area, level = nut2
# processing DEC0 area, level = nut2
# processing BE35 area, level = nut2
# processing PT18 area, level = nut2
# processing UKI3 area, level = nut2
# processing PL72 area, level = nut2
# processing UKL1 area, level = nut2
# processing UKI4 area, level = nut2
# processing DEB2 area, level = nut2
# processing DE94 area, level = nut2
# processing DEG0 area, level = nut2
# processing DE93 area, level = nut2
# processing UKF1 area, level = nut2
# processing RO41 area, level = nut2
# processing BA33 area, level = nut2
# processing NL13 area, level = nut2
# processing IE06 area, level = nut2
# processing ES64 area, level = nut2
# processing BA34 area, level = nut2
# processing NL41 area, level = nut2
# processing ES63 area, level = nut2
# processing BG32 area, level = nut2
# processing FRF2 area, level = nut2
# processing SE22 area, level = nut2
# processing ES23 area, level = nut2
# processing UKM9 area, level = nut2
# processing UKG3 area, level = nut2
# processing BA21 area, level = nut2
# processing TRA2 area, level = nut2
# processing PL92 area, level = nut2
# processing FRG0 area, level = nut2
# processing ES24 area, level = nut2
# processing BA26 area, level = nut2
# processing DE21 area, level = nut2
# processing DE73 area, level = nut2
# processing PT15 area, level = nut2
# processing DE26 area, level = nut2
# processing FI1B area, level = nut2
# processing DK03 area, level = nut2
# processing ES12 area, level = nut2
# processing ITG1 area, level = nut2
# processing AL01 area, level = nut2
# processing DK04 area, level = nut2
# processing FRD1 area, level = nut2
# processing HU21 area, level = nut2
# processing NL22 area, level = nut2
# processing ITF4 area, level = nut2
# processing ITC1 area, level = nut2
# processing RO22 area, level = nut2
# processing RS11 area, level = nut2
# processing TRC1 area, level = nut2
# processing ITF3 area, level = nut2
# processing ES52 area, level = nut2
# processing HU33 area, level = nut2
# processing DE50 area, level = nut2
# processing BA27 area, level = nut2
# processing ES70 area, level = nut2
# processing BA20 area, level = nut2
# processing UKG2 area, level = nut2
# processing UKM8 area, level = nut2
# processing ES22 area, level = nut2
# processing SE31 area, level = nut2
# processing DE27 area, level = nut2
# processing DE72 area, level = nut2
# processing HU11 area, level = nut2
# processing BG33 area, level = nut2
# processing ES62 area, level = nut2
# processing FRF3 area, level = nut2
# processing RS21 area, level = nut2
# processing PL81 area, level = nut2
# processing BA35 area, level = nut2
# processing RO12 area, level = nut2
# processing UKC2 area, level = nut2
# processing BG34 area, level = nut2
# processing ES30 area, level = nut2
# processing FRC1 area, level = nut2
# processing BA32 area, level = nut2
# processing NL12 area, level = nut2
# processing DE60 area, level = nut2
# processing SE23 area, level = nut2
# processing MT00 area, level = nut2
# processing SK01 area, level = nut2
# processing FRE2 area, level = nut2
# processing ES53 area, level = nut2
# processing ITF2 area, level = nut2
# processing ITF5 area, level = nut2
# processing NL23 area, level = nut2
# processing TR81 area, level = nut2
# processing UKE1 area, level = nut2
# processing SE12 area, level = nut2
# processing HU32 area, level = nut2
# processing PT30 area, level = nut2
# processing UKD4 area, level = nut2
# processing RO31 area, level = nut2
# processing DK05 area, level = nut2
# processing ES41 area, level = nut2
# processing FI1D area, level = nut2
# processing TRB2 area, level = nut2
# processing UKD3 area, level = nut2
# processing CY00 area, level = nut2
# processing BA11 area, level = nut2
# processing NL31 area, level = nut2
# processing ES13 area, level = nut2
# processing DK02 area, level = nut2
# processing FI1C area, level = nut2
# processing BG42 area, level = nut2
# processing FI19 area, level = nut2
# processing HR03 area, level = nut2
# processing LV00 area, level = nut2
# processing DE11 area, level = nut2
# processing HR04 area, level = nut2
# processing PT11 area, level = nut2
# processing DE22 area, level = nut2
# processing SE33 area, level = nut2
# processing PT16 area, level = nut2
# processing DE25 area, level = nut2
# processing BA22 area, level = nut2
# processing TRA1 area, level = nut2
# processing PL91 area, level = nut2
# processing BA25 area, level = nut2
# processing DE30 area, level = nut2
# processing SE21 area, level = nut2
# processing RO42 area, level = nut2
# processing UKF2 area, level = nut2
# processing IE05 area, level = nut2
# processing PL84 area, level = nut2
# processing BA37 area, level = nut2
# processing NL42 area, level = nut2
# processing BG31 area, level = nut2
# processing FRF1 area, level = nut2
# processing NL21 area, level = nut2
# processing UKE3 area, level = nut2
# processing TR83 area, level = nut2
# processing SK04 area, level = nut2
# processing ITC2 area, level = nut2
# processing UKE4 area, level = nut2
# processing RO21 area, level = nut2
# processing TRC2 area, level = nut2
# processing RS12 area, level = nut2
# processing SK03 area, level = nut2
# processing ES51 area, level = nut2
# processing PT20 area, level = nut2
# processing DE13 area, level = nut2
# processing HU22 area, level = nut2
# processing DE14 area, level = nut2
# processing ES11 area, level = nut2
# processing UKD1 area, level = nut2
# processing NL33 area, level = nut2
# processing ES43 area, level = nut2
# processing AL02 area, level = nut2
# processing ITG2 area, level = nut2
# processing FRD2 area, level = nut2
# processing UKD6 area, level = nut2
# processing NL34 area, level = nut2
# processing ES61 area, level = nut2
# processing PL82 area, level = nut2
# processing RS22 area, level = nut2
# processing UKC1 area, level = nut2
# processing RO11 area, level = nut2
# processing BA36 area, level = nut2
# processing FRC2 area, level = nut2
# processing UKF3 area, level = nut2
# processing BA31 area, level = nut2
# processing NL11 area, level = nut2
# processing IE04 area, level = nut2
# processing SE32 area, level = nut2
# processing DE24 area, level = nut2
# processing DE71 area, level = nut2
# processing PT17 area, level = nut2
# processing CZ08 area, level = nut2
# processing HU12 area, level = nut2
# processing DE23 area, level = nut2
# processing BA24 area, level = nut2
# processing UKG1 area, level = nut2
# processing BA23 area, level = nut2
# processing FRB0 area, level = nut2
# processing ES21 area, level = nut2
# processing DE40 area, level = nut2
# processing DE12 area, level = nut2
# processing HU23 area, level = nut2
# processing RO32 area, level = nut2
# processing UKD7 area, level = nut2
# processing ES42 area, level = nut2
# processing AL03 area, level = nut2
# processing TRB1 area, level = nut2
# processing TR90 area, level = nut2
# processing NL32 area, level = nut2
# processing BG41 area, level = nut2
# processing DK01 area, level = nut2
# processing SE11 area, level = nut2
# processing HU31 area, level = nut2
# processing SK02 area, level = nut2
# processing FRE1 area, level = nut2
# processing TRC3 area, level = nut2
# processing ITC4 area, level = nut2
# processing ITF1 area, level = nut2
# processing ITC3 area, level = nut2
# processing ITF6 area, level = nut2
# processing TR82 area, level = nut2
# processing UKE2 area, level = nut2
# processing EL54 area, level = nut2
# processing AT31 area, level = nut2
# processing EL53 area, level = nut2
# processing DED4 area, level = nut2
# processing DEA1 area, level = nut2
# processing TR22 area, level = nut2
# processing CH01 area, level = nut2
# processing ITI3 area, level = nut2
# processing PL41 area, level = nut2
# processing CH06 area, level = nut2
# processing ITI4 area, level = nut2
# processing NO02 area, level = nut2
# processing EL41 area, level = nut2
# processing NO05 area, level = nut2
# processing FRK1 area, level = nut2
# processing ITH1 area, level = nut2
# processing UKN0 area, level = nut2
# processing UKK2 area, level = nut2
# processing TR62 area, level = nut2
# processing LI00 area, level = nut2
# processing DEF0 area, level = nut2
# processing CZ02 area, level = nut2
# processing AT12 area, level = nut2
# processing CZ05 area, level = nut2
# processing FRH0 area, level = nut2
# processing PL62 area, level = nut2
# processing BA29 area, level = nut2
# processing UKH3 area, level = nut2
# processing UKM6 area, level = nut2
# processing BE25 area, level = nut2
# processing DE91 area, level = nut2
# processing EL65 area, level = nut2
# processing EL30 area, level = nut2
# processing BE22 area, level = nut2
# processing EL62 area, level = nut2
# processing MK00 area, level = nut2
# processing UKI6 area, level = nut2
# processing FRI2 area, level = nut2
# processing TR41 area, level = nut2
# processing FRL0 area, level = nut2
# processing EE00 area, level = nut2
# processing PL22 area, level = nut2
# processing SI03 area, level = nut2
# processing NO04 area, level = nut2
# processing SI04 area, level = nut2
# processing AT22 area, level = nut2
# processing NO03 area, level = nut2
# processing DEE0 area, level = nut2
# processing TR63 area, level = nut2
# processing UKK3 area, level = nut2
# processing TR31 area, level = nut2
# processing UKK4 area, level = nut2
# processing PL52 area, level = nut2
# processing DED5 area, level = nut2
# processing EL52 area, level = nut2
# processing DED2 area, level = nut2
# processing LT02 area, level = nut2
# processing CH07 area, level = nut2
# processing FRY1 area, level = nut2
# processing TR71 area, level = nut2
# processing UKJ1 area, level = nut2
# processing ITI2 area, level = nut2
# processing FRJ2 area, level = nut2
# processing IS00 area, level = nut2
# processing DEB1 area, level = nut2
# processing EL63 area, level = nut2
# processing BE23 area, level = nut2
# processing EL64 area, level = nut2
# processing BE24 area, level = nut2
# processing PL71 area, level = nut2
# processing FRI3 area, level = nut2
# processing UKL2 area, level = nut2
# processing UKI7 area, level = nut2
# processing BE31 area, level = nut2
# processing CZ04 area, level = nut2
# processing AT13 area, level = nut2
# processing CZ03 area, level = nut2
# processing ME00 area, level = nut2
# processing UKM7 area, level = nut2
# processing TR52 area, level = nut2
# processing UKH2 area, level = nut2
# processing BA28 area, level = nut2
# processing FI20 area, level = nut2
# processing PL63 area, level = nut2
# H_ERA5_ECMW_T639_GHI_0000m_Euro_nut2_S200001010000_E200001012300_ACC_MAP_01h_NA-_noc_org_NA_NA---_NA---_NA---.csv created
# H ✓
# ERA5 ✓
# ECMW ✓
# T639 ✓
# GHI ✓
# 0000m ✓
# Euro ✓
# nut2 ✓
# SYYYYMMDDhhmm ✓
# EYYYYMMDDhhmm ✓
# ACC ✓
# MAP ✓
# 01h ✓
# NA- ✓
# noc ✓
# org ✓
# NA ✓
# NA--- ✓
# NA--- ✓
# NA--- ✓
# There are 20 of 20 required elements in the filename
# nut2 processing complete
# time elapsed in seconds:
# 33.29509210586548
